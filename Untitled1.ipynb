# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/sharan/Desktop/results.csv")

# %%
df
# Out:
#              date      home_team away_team  home_score  away_score  \
# 0      1872-11-30       Scotland   England           0           0
# 1      1873-03-08        England  Scotland           4           2
# 2      1874-03-07       Scotland   England           2           1
# 3      1875-03-06        England  Scotland           2           2
# 4      1876-03-04       Scotland   England           3           0
# ...           ...            ...       ...         ...         ...
# 43747  2022-06-14        Moldova   Andorra           2           1
# 43748  2022-06-14  Liechtenstein    Latvia           0           2
# 43749  2022-06-14          Chile     Ghana           0           0
# 43750  2022-06-14          Japan   Tunisia           0           3
# 43751  2022-06-14    South Korea     Egypt           4           1
#
#                 tournament      city        country  neutral
# 0                 Friendly   Glasgow       Scotland    False
# ...

# %%
df.describe()
# Out:
#          home_score    away_score
# count  43752.000000  43752.000000
# mean       1.740126      1.180129
# std        1.749672      1.397021
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df.isnull().sum()
#checking for missing values
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df = df.loc[(df["date"] >= "2019-01-01")]
#removing data before 2019-01-01 for recent form of the teams to acquire best results

# %%
df
# Out:
#              date             home_team  away_team  home_score  away_score  \
# 40612  2019-01-02                  Oman   Thailand           2           0
# 40613  2019-01-05  United Arab Emirates    Bahrain           1           1
# 40614  2019-01-06              Thailand      India           1           4
# 40615  2019-01-06             Australia     Jordan           0           1
# 40616  2019-01-06                 Syria  Palestine           0           0
# ...           ...                   ...        ...         ...         ...
# 43747  2022-06-14               Moldova    Andorra           2           1
# 43748  2022-06-14         Liechtenstein     Latvia           0           2
# 43749  2022-06-14                 Chile      Ghana           0           0
# 43750  2022-06-14                 Japan    Tunisia           0           3
# 43751  2022-06-14           South Korea      Egypt           4           1
#
#                 tournament       city               country  neutral
# ...

# %%
fig=plt.figure(figsize=(10,5))
plt.boxplot([df["home_score"],df["away_score"]])
plt.xticks([1,2], ["Home Score", "Away Score"])
#checking for outliers
# Out:
# ([<matplotlib.axis.XTick at 0x1e43a5f3be0>,
# ...
#  [Text(1, 0, 'Home Score'), Text(2, 0, 'Away Score')])

# %%
df
# Out:
#              date             home_team  away_team  home_score  away_score  \
# 40612  2019-01-02                  Oman   Thailand           2           0
# 40613  2019-01-05  United Arab Emirates    Bahrain           1           1
# 40614  2019-01-06              Thailand      India           1           4
# 40615  2019-01-06             Australia     Jordan           0           1
# 40616  2019-01-06                 Syria  Palestine           0           0
# ...           ...                   ...        ...         ...         ...
# 43747  2022-06-14               Moldova    Andorra           2           1
# 43748  2022-06-14         Liechtenstein     Latvia           0           2
# 43749  2022-06-14                 Chile      Ghana           0           0
# 43750  2022-06-14                 Japan    Tunisia           0           3
# 43751  2022-06-14           South Korea      Egypt           4           1
#
#                 tournament       city               country  neutral
# ...

# %%
conditions=[df["home_score"]>df["away_score"],df["home_score"]==df["away_score"],df["home_score"]<df["away_score"]]
cases=["Win","Draw","Loss"]
df["result"]=np.select(conditions,cases)
# Out:
# C:\Users\sharan\AppData\Local\Temp\ipykernel_7836\1696099103.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["result"]=np.select(conditions,cases)

# %%
df
# Out:
#              date             home_team  away_team  home_score  away_score  \
# 40612  2019-01-02                  Oman   Thailand           2           0
# 40613  2019-01-05  United Arab Emirates    Bahrain           1           1
# 40614  2019-01-06              Thailand      India           1           4
# 40615  2019-01-06             Australia     Jordan           0           1
# 40616  2019-01-06                 Syria  Palestine           0           0
# ...           ...                   ...        ...         ...         ...
# 43747  2022-06-14               Moldova    Andorra           2           1
# 43748  2022-06-14         Liechtenstein     Latvia           0           2
# 43749  2022-06-14                 Chile      Ghana           0           0
# 43750  2022-06-14                 Japan    Tunisia           0           3
# 43751  2022-06-14           South Korea      Egypt           4           1
#
# ...

# %%
df["home_team"].value_counts()
# Out:
# United States           41
# Mexico                  34
# Morocco                 32
# Japan                   31
# United Arab Emirates    30
#                         ..
# Tonga                    1
# Macau                    1
# Kernow                   1
# Catalonia                1
# Cook Islands             1
# Name: home_team, Length: 240, dtype: int64

# %% [markdown]
# #240 countries

# %%
df["tournament"].value_counts()
# Out:
# FIFA World Cup qualification                  863
# Friendly                                      729
# UEFA Nations League                           277
# UEFA Euro qualification                       262
# CONCACAF Nations League                       173
# African Cup of Nations qualification          169
# African Cup of Nations                        104
# African Nations Championship qualification     64
# Gold Cup                                       62
# Copa América                                   54
# UEFA Euro                                      51
# AFC Asian Cup                                  51
# COSAFA Cup                                     44
# AFC Asian Cup qualification                    40
# Arab Cup                                       32
# Pacific Games                                  22
# CONIFA European Football Cup                   20
# Inter Games Football Tournament                19
# CONCACAF Nations League qualification          18
# ...

# %%
df
# Out:
#              date             home_team  away_team  home_score  away_score  \
# 40612  2019-01-02                  Oman   Thailand           2           0
# 40613  2019-01-05  United Arab Emirates    Bahrain           1           1
# 40614  2019-01-06              Thailand      India           1           4
# 40615  2019-01-06             Australia     Jordan           0           1
# 40616  2019-01-06                 Syria  Palestine           0           0
# ...           ...                   ...        ...         ...         ...
# 43747  2022-06-14               Moldova    Andorra           2           1
# 43748  2022-06-14         Liechtenstein     Latvia           0           2
# 43749  2022-06-14                 Chile      Ghana           0           0
# 43750  2022-06-14                 Japan    Tunisia           0           3
# 43751  2022-06-14           South Korea      Egypt           4           1
#
# ...
